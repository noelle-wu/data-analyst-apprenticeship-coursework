# %% [markdown]
# **Following guidelines set expectations for participant behaviour during workshop activities. They also ensure that the class environment is welcoming, inclusive, and respectful.**
# - Where a discussion is taking place, allow everyone a chance to speak
# - Listen respectfully, without interrupting and with an open mind to understanding others’ views
# - Be professional and productive, and always share your ideas, your opinion matters, we all can learn something from each other
# - Personal information that comes up in the conversation should be kept confidential
# - Avoid inflammatory language
# - Avoid assumptions about any member of the class or generalisations about social groups

# %% [markdown]
# **You have now joined a group of fellow analysts in a workshop:**
# #### Outcomes:
#
# - To be able to answer the questions to test your knowledge of Python Programming Syntax
#
#
# #### Note:
# - We understand learners will progress at their own speed
# - Tutors will be on hand to answer questions

# %% [markdown]
# # Conditional expressions

# %% [markdown]
# - Make sure you run the following code cell before you attempt any of the questions
# - This will create `age` and `min_age` variables. These will be referenced during following questions

# %%
my_age = 10
min_age = 18

print(my_age)
print(min_age)
# Out:
# 10
# 18

# %% [markdown]
# **Q1)** Write an expression that prints **'You are not allowed in'** if `my_age < min_age`: Also add an `else` statement, that prints **'Welcome'**

# %%
#add your code below

if my_age < min_age:
    print('You are not allowed in')
    
else: 
    print('Welcome')
# Out:
# You are not allowed in

# %% [markdown]
# **Q2)** Copy your code from above to the cell below, then do the following:
#
# - Add a second `print()` statement to be executed if `age < min_age`, which uses string formatting to print **'Come back in `<x>` years'**, where `<x>` is the difference between `min_age` and `my_age`
# - You can make use of `f-strings` or the `.format()` method while creating the `print()` statement

# %%
#add your code below

if my_age < min_age:

    print('You are not allowed in')

    print(f'Come back in {min_age-my_age} years')

else:

    print('Welcome')
# Out:
# You are not allowed in
# Come back in 8 years

# %% [markdown]
# ## Iteration - for loops

# %% [markdown]
# - Make sure you run the following code cell before you attempt any of the questions
# - This will create `ages`, `names` and `details` variables. These will be referenced during following questions

# %%
ages = [17, 22, 14, 55, 23, 19, 16, 21, 33, 42, 25]
names = ['John', 'Mandy', 'Siri', 'Robert', 'Saul', 'Paulina', 'Fay', 'Mahmood', 'Ben', 'Angela', 'Vicky']
details = list(zip(names, ages))

# %% [markdown]
# You don't need to worry about understanding the code above. The outcome is three variables:
#
# - `ages`: a list of ages
# - `names`: a list of names. Each of the people's names have their ages shown in `ages`, and in the same order
# - `details`: a list of tuples, as can be seen by running the cell below

# %%
details
# Out:
# [('John', 17),
#  ('Mandy', 22),
#  ('Siri', 14),
#  ('Robert', 55),
#  ('Saul', 23),
#  ('Paulina', 19),
#  ('Fay', 16),
#  ('Mahmood', 21),
#  ('Ben', 33),
#  ('Angela', 42),
#  ('Vicky', 25)]

# %% [markdown]
# **Example1:** You have been given the below code that counts the number of elements in `ages` list. This is a step-by-step process where you:
# - First create a counter, say variable `counter`, and set its value to `0`
# - Then use a `for` loop to iterate through the list `ages`, incrementing `counter` on each loop by `1`
# - At the end, `print` the statement **'The number of ages in the list is `<your result>`**, where `<your result>` is the new value of `counter`
# - You can make use of `f-strings` or the `.format()` method while creating the `print()` statement

# %%
counter = 0

for age in ages:
    counter = counter + 1

print(f'The number of ages in the list is {counter}')
# Out:
# The number of ages in the list is 11

# %% [markdown]
# **Example2:** You have been given the below code that use a `for` loop to iterate through each tuple in `details` list**
# - If the `age` value in tuple is less than `min_age`, print **'`<name>` is too young'
# - `<name>` is the `name` value appearing in the tuple

# %%
details
# Out:
# [('John', 17),
#  ('Mandy', 22),
#  ('Siri', 14),
#  ('Robert', 55),
#  ('Saul', 23),
#  ('Paulina', 19),
#  ('Fay', 16),
#  ('Mahmood', 21),
#  ('Ben', 33),
#  ('Angela', 42),
#  ('Vicky', 25)]

# %%
min_age = 18

for person in details:
    if person[1] < min_age:
        print(f'{person[0]} is too young')
# Out:
# John is too young
# Siri is too young
# Fay is too young

# %% [markdown]
# **Q3)** Copy your code from above into the cell below:
#
# - Create a variable, `number`, before the `for` loop and set its value to `0`
# - Next, add a further statement to the `for` loop to count the number of people who are not too young (this is captured by the variable `number`)
# - `print` a final statement **'The number of people who can attend is `<number>`'**
# - you can make use of `f-strings` or the `.format()` method while creating the `print()` statement

# %%
#add your code below
number = 0
min_age = 18

for person in details:
    if person[1] < min_age:
        print(f'{person[0]} is too young')
        
    else:
        number +=1
print(f'The number of people who can attend is {number}')
# Out:
# John is too young
# Siri is too young
# Fay is too young
# The number of people who can attend is 8

# %% [markdown]
# **Example3:** You have been given the below code that prints out a single list of those who are too young and those who aren't. This is a step-by-step process where you:
#
# - Create two empty lists called `refused` and `inside` respectively
# - Then loop through `details` and use `.append()` to add the person's `name` to `refused` list if they are too young, and to `inside` list otherwise. (See the Introduction to Python lessons if you want to refresh your memory of `.append()`)
# - `Print` out both lists

# %%
refused = []
inside = []

for person in details:
    if person[1] < min_age:
        refused.append(person[0])
    else:
        inside.append(person[0])

print(inside)
print(refused)
# Out:
# ['Mandy', 'Robert', 'Saul', 'Paulina', 'Mahmood', 'Ben', 'Angela', 'Vicky']
# ['John', 'Siri', 'Fay']

# %% [markdown]
# **Q4)** `len()` function can be used to calculate the number of people in the  `inside` and `refused` lists.
#
# - Now calculate the percentage of all people who are in `inside` list
# -`Print` the statement **'x% of people are inside'**. (See the Introduction to Python lessons if you want to refresh your memory of `len()` function)
# - you can make use of `f-strings` or the `.format()` method while creating the `print()` statement

# %%
#add your code below

# Calculate the percentage of people inside

percent = (len(inside) / (len(inside) + len(refused)) * 100)
print(f'{percent}% of people are inside')
# Out:
# 72.72727272727273% of people are inside

# %% [markdown]
# **Q5)** As you can see, above result doesn't look very reader-friendly!
#
# - Use `round()` function to print out the result again, but only to one decimal place
# - see the Introduction to Python lessons if you want to refresh your memory on `round()` function

# %%
# Calculate the percentage of people inside
total_people = len(details)
inside_percentage = (len(inside) / total_people) * 100

# Print the result using round() for one decimal place
print(f"{round(inside_percentage, 1)}% of people are inside")
# Out:
# 72.7% of people are inside

# %% [markdown]
# **Q6)** Make sure you run the following code cell before you attempt any of the question.
# - It sets the capacity of a venue, `capacity` to the value `5`, and creates an empty list, `reserves`, for those who are eligible, ie, over `min_age`, but for whom there is not enough room

# %%
capacity = 5
reserves = []

# %% [markdown]
# Copy the code block from above **Example3:** to the cell below and update it so that:
#
# - if the `age` is `>= min_age` but `len(inside) >= capacity`, then `.append()` the `name` to the `reserves` list, otherwise `.append()` the `name` to the `inside` list
# - if they are too young: `age` is `< min_age` use `.append()` to add the person's `name` to `refused` list
# - Print out all three lists, ie, `inside`, `reserves` and `refused`

# %% [markdown]
# **use the structure below as a guide while formulating your answer**
#
# ```python
#
#     for <statement>:
#         if <statement>:
#             if <statement>:
#                 .....
#             else:
#                 .....
#         else:
#             .....
#
#     print(.....)
#     print(.....)
#     print(.....)
#
# ```

# %%
#add your code below


refused = []
inside = []

for person in details:
    if person[1] >= min_age:
        
        if len(inside) >= capacity:            
            reserves.append(person[0])
        
        else:    
            inside.append(person[0])
        
    else:
        refused.append(person[0])

print(inside)
print(reserves)
print(refused)
# Out:
# ['Mandy', 'Robert', 'Saul', 'Paulina', 'Mahmood']
# ['Ben', 'Angela', 'Vicky']
# ['John', 'Siri', 'Fay']
